# %% [markdown]
# # Capítulo 10: Checklist e Próximos Passos
#
# Este notebook acompanha os exemplos práticos do script Python.

# %%
# -*- coding: utf-8 -*-"""Capítulo 10: Checklist e Próximos Passos⚠️ AVISO: Códigos para fins educacionais. NÃO use exemplos vulneráveis em produção."""import hashlibimport sqlite3# ==============================================================================# SETUP# ==============================================================================print(f"--- Iniciando Capítulo 10: Checklist e Próximos Passos ---")# Mock de banco de dados para exemplosdef get_db():    conn = sqlite3.connect(':memory:')    cursor = conn.cursor()    cursor.execute("CREATE TABLE users (id INTEGER PRIMARY KEY, username TEXT, password TEXT)")    cursor.execute("INSERT INTO users (username, password) VALUES ('admin', '12345')")    cursor.execute("INSERT INTO users (username, password) VALUES ('user', 'abcde')")    conn.commit()    return conn# ==============================================================================# CONTEÚDO DO CAPÍTULO# ==============================================================================

# %% [markdown]
# ## Code Review

# %%
# ----------------------------------------
# Tópico: Code Review

# %% [markdown]
# ## Exemplo

# %%
# ----------------------------------------
print(f"\n>>> Explorando: Code Review")

def exemplo_vulneravel_code_review():
    """
    ❌ EXEMPLO VULNERÁVEL
    Demonstração de como NÃO fazer.
    """
    print("  [X] Executando código vulnerável...")
    # Implementação insegura aqui
    pass

def exemplo_seguro_code_review():
    """
    ✅ EXEMPLO SEGURO
    Demonstração da correção/boas práticas.
    """
    print("  [V] Executando código seguro...")
    # Implementação segura aqui
    pass

# Execução
# exemplo_vulneravel_code_review()
# exemplo_seguro_code_review()

# %% [markdown]
# ## Pentest Basics

# %%
# ----------------------------------------
# Tópico: Pentest Basics

# %% [markdown]
# ## Exemplo

# %%
# ----------------------------------------
print(f"\n>>> Explorando: Pentest Basics")

def exemplo_vulneravel_pentest_basics():
    """
    ❌ EXEMPLO VULNERÁVEL
    Demonstração de como NÃO fazer.
    """
    print("  [X] Executando código vulnerável...")
    # Implementação insegura aqui
    pass

def exemplo_seguro_pentest_basics():
    """
    ✅ EXEMPLO SEGURO
    Demonstração da correção/boas práticas.
    """
    print("  [V] Executando código seguro...")
    # Implementação segura aqui
    pass

# Execução
# exemplo_vulneravel_pentest_basics()
# exemplo_seguro_pentest_basics()

# %% [markdown]
# ## Security Automation

# %%
# ----------------------------------------
# Tópico: Security Automation

# %% [markdown]
# ## Exemplo

# %%
# ----------------------------------------
print(f"\n>>> Explorando: Security Automation")

def exemplo_vulneravel_security_automation():
    """
    ❌ EXEMPLO VULNERÁVEL
    Demonstração de como NÃO fazer.
    """
    print("  [X] Executando código vulnerável...")
    # Implementação insegura aqui
    pass

def exemplo_seguro_security_automation():
    """
    ✅ EXEMPLO SEGURO
    Demonstração da correção/boas práticas.
    """
    print("  [V] Executando código seguro...")
    # Implementação segura aqui
    pass

# Execução
# exemplo_vulneravel_security_automation()
# exemplo_seguro_security_automation()

print("\n--- Capítulo concluído com sucesso ---")
