# %% [markdown]
# # Capítulo 02 - Injeção SQL
#
# Este notebook demonstra técnicas seguras de prevenção contra injeção SQL.

# %%
# -*- coding: utf-8 -*-
"""
capitulo-02-injecao-sql
"""

# capitulo-02-injecao-sql
import duckdb
import os

# %% [markdown]
# ## 2. Imports Necessários
#
# Importando as bibliotecas que serão utilizadas.

# %%
# Instalação de dependências
# %pip install psycopg2-binary duckdb -q

# %% [markdown]
# ## 1. Instalação de Dependências
#
# Instalando bibliotecas necessárias para os exemplos.

# %%
# Exemplo/Bloco 1
import psycopg2

# SEGURO! ✅
def login(username, password):
    conn = psycopg2.connect(database="mydb")
    cursor = conn.cursor()

    # Prepared statement com %s
    query = "SELECT * FROM users WHERE username = %s AND password = %s"
    cursor.execute(query, (username, password))

    result = cursor.fetchone()
    cursor.close()
    conn.close()

    return result

# %% [markdown]
# ## 3. Exemplo de Login Seguro
#
# Implementação segura usando prepared statements para prevenir SQL injection.
