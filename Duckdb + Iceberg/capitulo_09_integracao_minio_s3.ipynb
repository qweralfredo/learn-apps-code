# %%
# %pip install s3fs boto3 adlfs gcsfs
# Out:
# Requirement already satisfied: s3fs in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2026.1.0)
# Requirement already satisfied: boto3 in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (1.42.30)
# Requirement already satisfied: adlfs in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2025.8.0)
# Requirement already satisfied: gcsfs in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2026.1.0)
# Requirement already satisfied: aiobotocore<4.0.0,>=2.5.4 in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from s3fs) (3.1.1)
# Requirement already satisfied: fsspec==2026.1.0 in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from s3fs) (2026.1.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from s3fs) (3.13.3)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiobotocore<4.0.0,>=2.5.4->s3fs) (0.13.0)
# Requirement already satisfied: botocore<1.42.31,>=1.41.0 in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiobotocore<4.0.0,>=2.5.4->s3fs) (1.42.30)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiobotocore<4.0.0,>=2.5.4->s3fs) (2.9.0.post0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiobotocore<4.0.0,>=2.5.4->s3fs) (1.0.1)
# Requirement already satisfied: multidict<7.0.0,>=6.0.0 in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiobotocore<4.0.0,>=2.5.4->s3fs) (6.0.5)
# Requirement already satisfied: wrapt<3.0.0,>=1.10.10 in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiobotocore<4.0.0,>=2.5.4->s3fs) (1.16.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.4.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.22.0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from botocore<1.42.31,>=1.41.0->aiobotocore<4.0.0,>=2.5.4->s3fs) (2.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil<3.0.0,>=2.1->aiobotocore<4.0.0,>=2.5.4->s3fs) (1.16.0)
# Requirement already satisfied: idna>=2.0 in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (3.7)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from boto3) (0.16.0)
# Requirement already satisfied: azure-core<2.0.0,>=1.28.0 in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from adlfs) (1.38.0)
# Requirement already satisfied: azure-datalake-store<0.1,>=0.0.53 in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from adlfs) (0.0.53)
# Requirement already satisfied: azure-identity in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from adlfs) (1.25.1)
# Requirement already satisfied: azure-storage-blob>=12.17.0 in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from adlfs) (12.28.0)
# Requirement already satisfied: requests>=2.21.0 in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from azure-core<2.0.0,>=1.28.0->adlfs) (2.31.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from azure-core<2.0.0,>=1.28.0->adlfs) (4.15.0)
# Requirement already satisfied: cffi in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from azure-datalake-store<0.1,>=0.0.53->adlfs) (1.17.1)
# Requirement already satisfied: msal<2,>=1.16.0 in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from azure-datalake-store<0.1,>=0.0.53->adlfs) (1.34.0)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from PyJWT[crypto]<3,>=1.0.0->msal<2,>=1.16.0->azure-datalake-store<0.1,>=0.0.53->adlfs) (2.10.1)
# Requirement already satisfied: cryptography<49,>=2.5 in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from msal<2,>=1.16.0->azure-datalake-store<0.1,>=0.0.53->adlfs) (44.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->adlfs) (3.4.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->adlfs) (2025.11.12)
# Requirement already satisfied: decorator>4.1.2 in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from gcsfs) (5.1.1)
# Requirement already satisfied: google-auth>=1.2 in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from gcsfs) (2.43.0)
# Requirement already satisfied: google-auth-oauthlib in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from gcsfs) (1.2.2)
# Requirement already satisfied: google-cloud-storage>=3.7.0 in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from gcsfs) (3.8.0)
# Requirement already satisfied: google-cloud-storage-control in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from gcsfs) (1.9.0)
# Requirement already satisfied: isodate>=0.6.1 in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from azure-storage-blob>=12.17.0->adlfs) (0.7.2)
# Requirement already satisfied: pycparser in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cffi->azure-datalake-store<0.1,>=0.0.53->adlfs) (2.22)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-auth>=1.2->gcsfs) (6.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-auth>=1.2->gcsfs) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-auth>=1.2->gcsfs) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from rsa<5,>=3.1.4->google-auth>=1.2->gcsfs) (0.6.1)
# Requirement already satisfied: google-api-core<3.0.0,>=2.27.0 in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-cloud-storage>=3.7.0->gcsfs) (2.28.1)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.2 in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-cloud-storage>=3.7.0->gcsfs) (2.4.3)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.7.2 in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-cloud-storage>=3.7.0->gcsfs) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-cloud-storage>=3.7.0->gcsfs) (1.6.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage>=3.7.0->gcsfs) (1.72.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage>=3.7.0->gcsfs) (4.25.3)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage>=3.7.0->gcsfs) (1.26.1)
# Requirement already satisfied: msal-extensions>=1.2.0 in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from azure-identity->adlfs) (1.3.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-auth-oauthlib->gcsfs) (2.0.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->gcsfs) (3.3.1)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-cloud-storage-control->gcsfs) (1.76.0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.14.0 in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-cloud-storage-control->gcsfs) (0.14.2)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in c:\users\alfre\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-storage-control->gcsfs) (1.62.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Capítulo 09 - Integração com MinIO (S3 Compatible)
#
# ## ☁️ Objetivo
#
# Até agora trabalhamos com o **Local Filesystem** (`warehouse: file://...`).
# Em produção, Data Lakes modernos utilizam **Object Stores** (S3, GCS, Azure Blob).
#
# Neste capítulo, vamos migrar nosso Lakehouse para um ambiente de nuvem simulado usando **MinIO**.
# O MinIO oferece uma API compatível com S3.
#
# ### Tópicos
# 1.  **Infraestrutura**: Subir MinIO via Docker Compose.
# 2.  **Configuração S3**: Configurar PyIceberg para falar S3 (`s3fs`).
# 3.  **Catálogo Híbrido**: Usar SQLite para metadata (Catalog Loca) mas S3 para dados (Warehouse Remoto).
# 4.  **Hands-on**: Criar e manipular a tabela `s3_sales`.
#
# ## 🐳 Requisitos de Infraestrutura
#
# Você precisa ter o **Docker** rodando.
# Na pasta deste projeto, criei um arquivo `docker-compose.yaml` com o MinIO.
#
# Para subir o serviço (execute no terminal):
# ```bash
# docker-compose up -d
# ```
# Isso vai criar o bucket `warehouse` automaticamente.
# Acesse o console em: http://localhost:9001 (User: `admin`, Pass: `password`)

# %%
import pyiceberg
from pyiceberg.catalog.sql import SqlCatalog
from pyiceberg.schema import Schema
from pyiceberg.types import NestedField, StringType, LongType, DoubleType, TimestampType
import pyarrow as pa
import pandas as pd
from datetime import datetime
import os
import s3fs

# Dependências extras para S3
# %pip install s3fs adlfs gcsfs boto3

S3_ENDPOINT = "http://localhost:9000"
S3_ACCESS_KEY = "admin"
S3_SECRET_KEY = "password"
BUCKET_NAME = "warehouse"

# Garantir que o Bucket existe via s3fs
try:
    fs = s3fs.S3FileSystem(
        client_kwargs={'endpoint_url': S3_ENDPOINT, 'aws_access_key_id': S3_ACCESS_KEY, 'aws_secret_access_key': S3_SECRET_KEY},
        key=S3_ACCESS_KEY, secret=S3_SECRET_KEY
    )
    if not fs.exists(BUCKET_NAME):
        print(f"🪣 Criando bucket '{BUCKET_NAME}'...")
        fs.mkdir(BUCKET_NAME)
    else:
        print(f"✅ Bucket '{BUCKET_NAME}' já existe.")
except Exception as e:
    print(f"⚠️ Erro ao verificar bucket: {e}")

# Configuração do Catálogo S3
catalog = SqlCatalog(
    "minio_catalog",
    **{
        "uri": "sqlite:///iceberg_warehouse/s3_catalog.db",
        "warehouse": f"s3://{BUCKET_NAME}/iceberg",
        "s3.endpoint": S3_ENDPOINT,
        "s3.access-key-id": S3_ACCESS_KEY,
        "s3.secret-access-key": S3_SECRET_KEY,
    }
)

print("Catálogo configurado para MinIO!")
# Out:
# ✅ Bucket 'warehouse' já existe.
# Catálogo configurado para MinIO!

# %% [markdown]
# ## 1. Validando Conexão
#
# Vamos tentar criar um Namespace no S3. Se o MinIO estiver offline ou as credenciais erradas, isso falhará.
# Se o bucket `warehouse` não existir (o docker-compose tenta criar), pode falhar também (necessário criar bucket antes).

# %%
try:
    catalog.create_namespace("s3_sales_db")
    print("✅ Namespace 's3_sales_db' criado no catálogo.")
except Exception as e:
    print(f"⚠️ Aviso (pode já existir): {e}")

# Listar namespaces
print(f"Namespaces: {catalog.list_namespaces()}")
# Out:
# ⚠️ Aviso (pode já existir): Namespace s3_sales_db already exists
# Namespaces: [('s3_sales_db',)]

# %% [markdown]
# ## 2. Criando Tabela no S3
#
# Vamos definir o schema e criar a tabela `s3_sales_db.cloud_sales`.
# Os arquivos Parquet e Metadata JSON serão gravados no MinIO.

# %%
schema = Schema(
    NestedField(1, "id", LongType(), required=True),
    NestedField(2, "ts", TimestampType(), required=True),
    NestedField(3, "region", StringType(), required=False),
    NestedField(4, "value", DoubleType(), required=False)
)

table_name = "s3_sales_db.cloud_sales"

try:
    tbl = catalog.create_table(table_name, schema)
    print(f"✅ Tabela Criada: {tbl.location()}")
except Exception as e:
    tbl = catalog.load_table(table_name)
    print(f"✅ Tabela Carregada: {tbl.location()}")

# Inserindo dados
df = pd.DataFrame({
    'id': [1, 2, 3],
    'ts': [datetime.now()] * 3,
    'region': ['us-east-1', 'eu-west-1', 'sa-east-1'],
    'value': [100.50, 200.00, 300.99]
})
df['ts'] = df['ts'].astype('datetime64[us]')
schema_pa = pa.schema([
    ('id', pa.int64(), False),
    ('ts', pa.timestamp('us'), False),
    ('region', pa.string()),
    ('value', pa.float64())
])

print("\nEnviando dados para o MinIO...")
tbl.append(pa.Table.from_pandas(df, schema=schema_pa))
print("Dados persistidos! Verifique no console do MinIO (http://localhost:9001/browser/warehouse/iceberg/s3_sales_db/cloud_sales)")
# Out:
# ✅ Tabela Carregada: s3://warehouse/iceberg/s3_sales_db/cloud_sales
#
# Enviando dados para o MinIO...
# Dados persistidos! Verifique no console do MinIO (http://localhost:9001/browser/warehouse/iceberg/s3_sales_db/cloud_sales)

# %% [markdown]
# ## 3. Leitura Transparente
#
# Para o usuário final (você), ler do S3 ou do disco local é transparente.
# A API do `scan()` cuida das chamadas HTTP/S3.

# %%
df_read = tbl.scan().to_pandas()
df_read
# Out:
#    id                         ts     region   value
# 0   1 2026-01-22 19:15:28.095038  us-east-1  100.50
# 1   2 2026-01-22 19:15:28.095038  eu-west-1  200.00
# 2   3 2026-01-22 19:15:28.095038  sa-east-1  300.99
# 3   1 2026-01-22 19:14:41.359617  us-east-1  100.50
# 4   2 2026-01-22 19:14:41.359617  eu-west-1  200.00
# 5   3 2026-01-22 19:14:41.359617  sa-east-1  300.99
