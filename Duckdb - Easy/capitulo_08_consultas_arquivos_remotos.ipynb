# %% [markdown]
# # 📦 Instalação de Dependências

# %%
# !pip install duckdb pandas -q

# %% [markdown]
# ---
#
# ## 🌐 Bloco 1: Arquivos HTTP/HTTPS
#
# DuckDB pode ler arquivos diretamente de URLs públicas.

# %%
import duckdb

con = duckdb.connect()

# Testar com arquivo público do DuckDB
try:
    result = con.sql("""
        SELECT count(*) as total_linhas
        FROM 'https://shell.duckdb.org/data/tpch/0_01/parquet/lineitem.parquet'
    """).fetchone()
    print(f"✅ Conectividade OK: {result[0]} linhas encontradas")
    
    # Ver amostra dos dados
    sample = con.sql("""
        SELECT *
        FROM 'https://shell.duckdb.org/data/tpch/0_01/parquet/lineitem.parquet'
        LIMIT 3
    """).df()
    print("\nAmostra dos dados:")
    print(sample)
    
except Exception as e:
    print(f"❌ Erro: {e}")

# %% [markdown]
# ---
#
# ## ☁️ Bloco 2: Amazon S3
#
# Configurando credenciais e consultando arquivos em buckets S3.

# %%
import duckdb

con = duckdb.connect()

# Configurar credenciais S3 (exemplo - substitua com suas credenciais)
try:
    con.sql("""
        CREATE SECRET secret (
            TYPE s3,
            PROVIDER config,
            KEY_ID 'YOUR_ACCESS_KEY_ID',
            SECRET 'YOUR_SECRET_ACCESS_KEY',
            REGION 'us-east-1'
        )
    """)
    print("✅ Secret S3 criado com sucesso")
    
    # Exemplo de consulta (ajuste o path do bucket)
    # result = con.sql("""
    #     SELECT *
    #     FROM 's3://seu-bucket/dados.parquet'
    #     LIMIT 10
    # """).df()
    
except Exception as e:
    print(f"⚠️ Nota: Configure suas credenciais S3 reais")
    print(f"Erro (esperado): {e}")

# %% [markdown]
# ---
#
# ## 🔗 Bloco 3: Combinação Local + Remoto
#
# Juntando dados locais com arquivos remotos em uma única query.

# %%
import duckdb
import pandas as pd

con = duckdb.connect()

# Criar dados locais de exemplo
usuarios_local = pd.DataFrame({
    'user_id': [1, 2, 3],
    'name': ['Alice', 'Bob', 'Carol'],
    'email': ['alice@example.com', 'bob@example.com', 'carol@example.com']
})

print("Usuários locais:")
print(usuarios_local)

# Exemplo de join local + remoto (conceito)
# Em produção, você faria algo como:
# result = con.sql("""
#     SELECT
#         l.user_id,
#         l.name,
#         l.email,
#         r.total_purchases
#     FROM usuarios_local l
#     JOIN 's3://bucket/user_stats.parquet' r
#         ON l.user_id = r.user_id
#     WHERE r.total_purchases > 1000
# """).df()

print("\n💡 Este padrão permite combinar dados locais com remotos sem download manual!")

# %% [markdown]
# # Capitulo 08 Consultas Arquivos Remotos
#
# Notebook gerado automaticamente a partir do código fonte python.
